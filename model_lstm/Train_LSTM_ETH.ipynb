# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/dophi/Desktop/Crypto_dashboard_predict/feature_engineering/ETHUSDT_1d_fe.csv')
df.head(5)
# Out:
#     open_time    open    high     low   close      volume        rsi  \
# 0  2017-08-31  384.64  389.36  377.78  384.79  4435.86855  58.464616
# 1  2017-09-01  386.44  394.39  383.18  388.46  4198.68434  59.690602
# 2  2017-09-02  388.58  394.32  320.08  343.14  8240.32724  42.864777
# 3  2017-09-03  343.56  367.28  320.08  341.77  5253.62211  42.474997
# 4  2017-09-04  339.29  344.55  267.94  283.77  6737.81061  30.026532
#
#    pct_change
# 0   -0.295390
# 1    0.953767
# 2  -11.666581
# 3   -0.399254
# 4  -16.970477

# %% [markdown]
# # Chia tập dữ liệu train/test tỉ lệ 80/20

# %%
y = df['close']
y
# Out:
# 0        384.79
# 1        388.46
# 2        343.14
# 3        341.77
# 4        283.77
#          ...
# 3027    3063.50
# 3028    2964.85
# 3029    2962.30
# 3030    2833.49
# 3031    2828.57
# Name: close, Length: 3032, dtype: float64

# %%
X = df.drop(['close', 'open_time'], axis=1)
X
# Out:
#          open     high      low        volume        rsi  pct_change
# 0      384.64   389.36   377.78    4435.86855  58.464616   -0.295390
# 1      386.44   394.39   383.18    4198.68434  59.690602    0.953767
# 2      388.58   394.32   320.08    8240.32724  42.864777  -11.666581
# 3      343.56   367.28   320.08    5253.62211  42.474997   -0.399254
# 4      339.29   344.55   267.94    6737.81061  30.026532  -16.970477
# ...       ...      ...      ...           ...        ...         ...
# 3027  3114.64  3129.54  3024.44  279058.35450  46.391290   -1.641923
# 3028  3063.49  3177.50  2894.57  520509.95550  42.487142   -3.220173
# 3029  2964.85  2981.87  2876.00  378293.11590  42.387840   -0.086008
# 3030  2962.30  3030.92  2791.02  497630.41620  37.606415   -4.348310
# 3031  2833.50  2997.40  2775.19  595253.79970  37.432727   -0.173637
#
# [3032 rows x 6 columns]

# %%
sequence_length = 30
test_days = 30
val_days = 30

N = len(df)
test_start = N - test_days
val_start = test_start - val_days
train_end = val_start   
window_start_val = val_start - sequence_length
window_start_test = test_start - sequence_length

# %%
# Train set
train_X = X.iloc[:train_end]
train_y = y.iloc[:train_end]

# %%
# Validation set
val_X = X.iloc[window_start_val:test_start]
val_y = y.iloc[window_start_val:test_start]

# %%
# Test set
test_X = X.iloc[window_start_test:]  # 60 ngày (cần cho tạo sequences)
test_y = y.iloc[test_start:]

# %%
print("Train X shape:", train_X.shape)
print("Train y shape:", train_y.shape)
print("Validation X shape:", val_X.shape)
print("Validation y shape:", val_y.shape)
print("Test X shape:", test_X.shape)
print("Test y shape:", test_y.shape)
# Out:
# Train X shape: (2972, 6)
# Train y shape: (2972,)
# Validation X shape: (60, 6)
# Validation y shape: (60,)
# Test X shape: (60, 6)
# Test y shape: (30,)

# %% [markdown]
# # Scale

# %%
# Scale (fit chỉ trên train)
scaler_X = StandardScaler()
scaled_train_X = scaler_X.fit_transform(train_X)
scaled_val_X = scaler_X.transform(val_X)
scaled_test_X = scaler_X.transform(test_X)

# %%
scaler_y = StandardScaler()
y_train_scaled = scaler_y.fit_transform(train_y.to_numpy().reshape(-1, 1))
y_val_scaled = scaler_y.transform(val_y.to_numpy().reshape(-1, 1))
y_test_scaled = scaler_y.transform(test_y.to_numpy().reshape(-1, 1))

# %% [markdown]
# # Lưu model scaler

# %%
import pickle

with open("scaler_X_ETH.pkl", "wb") as f:
    pickle.dump(scaler_X, f)

with open("scaler_y_ETH.pkl", "wb") as f:
    pickle.dump(scaler_y, f)

# %%
scaled_train_X
# Out:
# array([[-0.95321495, -0.96040925, -0.94619105, -1.17482887,  0.51761326,
#         -0.10411148],
#        [-0.95181655, -0.95660314, -0.94186737, -1.17535487,  0.60916678,
#          0.16501477],
#        [-0.95015399, -0.95665611, -0.99239035, -1.16639182, -0.64734314,
#         -2.55399174],
#        ...,
#        [ 1.77356985,  1.73420103,  1.69343011,  0.65628699, -0.89214352,
#         -0.38865797],
#        [ 1.72468775,  1.71700923,  1.80918457, -0.62867121, -0.74903469,
#          0.28363456],
#        [ 1.76945231,  1.79510631,  1.815566  , -0.27866058, -0.51997741,
#          0.47676066]])

# %% [markdown]
# # Tạo sequences(chuỗi) và label(nhãn) cho tập train và test

# %%
# Tạo chuỗi và nhãn cho tập train
sequence_length = 30 
X_train, y_train = [], []
for i in range(len(scaled_train_X) - sequence_length):
    X_train.append(scaled_train_X[i:i + sequence_length])
    y_train.append(y_train_scaled[i + sequence_length])
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
# Chuyển đổi dữ liệu sang Pytorch Tensors
import torch
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
print(X_train.shape, y_train.shape)
# Out:
# torch.Size([2942, 30, 6]) torch.Size([2942, 1])

# %% [markdown]
# kết quả: 2968: số mẫu huấn luyện trên tập train, 30 độ dài chuỗi, 6 số đặc trưng

# %%
X_val, y_val = [], []
for i in range(len(scaled_val_X) - sequence_length):
    X_val.append(scaled_val_X[i:i + sequence_length])
    y_val.append(y_val_scaled[i + sequence_length])
X_val, y_val = np.array(X_val), np.array(y_val)

# %%
X_val = torch.tensor(X_val, dtype=torch.float32)
y_val = torch.tensor(y_val, dtype=torch.float32)

# %% [markdown]
# kết quả: 30: số mẫu huấn luyện trên tập test, 30 độ dài chuỗi, 6 số đặc trưng

# %%
X_test = []
for i in range(len(scaled_test_X) - sequence_length):
    X_test.append(scaled_test_X[i:i + sequence_length])
X_test = np.array(X_test)

# %%
X_test = torch.tensor(X_test, dtype=torch.float32)

# %% [markdown]
# # khai báo mô hình LSTM

# %%
import torch.nn as nn
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size, dropout=0.2):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout)
        self.linear = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.linear(out[:, -1, :])
        return out

# %% [markdown]
# # Kiểm tra thiết bị nếu có gpu cuda thì sử dụng nếu không dùng cpu

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cpu

# %% [markdown]
# # Khởi tạo tham số cho mô hình

# %%
input_size = 6
num_layers = 2
hidden_size = 256
output_size = 1
dropout = 0.4
# sử dụng thiết bị tương ứng
model = LSTMModel(input_size, hidden_size, num_layers, output_size, dropout).to(device)

# %% [markdown]
# # Sử dụng chỉ số MSE cho loss và khởi tạo thêm optimizer là adam

# %%
import torch.optim as optim
loss_fn = nn.MSELoss(reduction='mean')
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# %% [markdown]
# khi huấn luyện mô hình sử dụng mse làm loss để trong quá trình huấn luyện, mô hình sẽ cố găng tập trung tối thiểu hoá các sai số lớn, vì vậy em chọn mse làm loss để bình phương sai số giữa giá trị dự đoán và giá trị thực tế.

# %% [markdown]
# # Tạo dataloader

# %%
from torch.utils.data import DataLoader, TensorDataset
batch_size = 32
train_dataset = TensorDataset(X_train, y_train)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
# Tạo DataLoader cho validation
val_dataset = TensorDataset(X_val, y_val)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# TensorDataset sẽ giúp ghép X, y thành cặp input và target
# còn Dataloader sẽ chia dữ liệu thành 32 batch ngoài ra shuffle tức là trộn dữ liệu sẽ áp dụng cho tập train điều này giúp mô hình không học vẹt, học theo thứ tự

# %% [markdown]
# # vòng lặp training

# %%
num_epochs = 250
train_hist = []
test_hist = []

# %%
#early stopping và lưu mô hình tốt nhất
best_loss = float('inf')   # lưu test loss thấp nhất
patience = 25               # cho phép 15 epoch không cải thiện
patience_counter = 0

for epoch in range(num_epochs):
    total_loss = 0.0
    model.train()
    for batch_X, batch_y in train_loader:
        batch_X, batch_y = batch_X.to(device), batch_y.to(device)
        predictions = model(batch_X)
        loss = loss_fn(predictions, batch_y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    average_loss = total_loss / len(train_loader)
    train_hist.append(average_loss)

    # Đánh giá trên VALIDATION (không phải test)
    model.eval()
    with torch.no_grad():
        total_val_loss = 0.0
        for batch_X_val, batch_y_val in val_loader:
            batch_X_val, batch_y_val = batch_X_val.to(device), batch_y_val.to(device)
            predictions_val = model(batch_X_val)
            val_loss = loss_fn(predictions_val, batch_y_val)
            total_val_loss += val_loss.item()

        average_val_loss = total_val_loss / len(val_loader)

    if (epoch + 1) % 10 == 0:
        print(f'Epoch [{epoch + 1}/{num_epochs}] - Train Loss: {average_loss:.4f}, Val Loss: {average_val_loss:.4f}')
    
    # Early stopping dựa trên VALIDATION LOSS
    if average_val_loss < best_loss:
        best_loss = average_val_loss
        torch.save(model.state_dict(), 'best_model_eth.pth')
        patience_counter = 0
    else:
        patience_counter += 1
        if patience_counter >= patience:
            print(f"Stop early tại epoch {epoch+1}")
            break
# Out:
# Epoch [10/250] - Train Loss: 0.0075, Val Loss: 0.0240
# Epoch [20/250] - Train Loss: 0.0059, Val Loss: 0.0109
# Epoch [30/250] - Train Loss: 0.0056, Val Loss: 0.0121
# Epoch [40/250] - Train Loss: 0.0056, Val Loss: 0.0117
# Epoch [50/250] - Train Loss: 0.0055, Val Loss: 0.0144
# Epoch [60/250] - Train Loss: 0.0058, Val Loss: 0.0119
# Epoch [70/250] - Train Loss: 0.0059, Val Loss: 0.0113
# Epoch [80/250] - Train Loss: 0.0051, Val Loss: 0.0078
# Epoch [90/250] - Train Loss: 0.0053, Val Loss: 0.0159
# Epoch [100/250] - Train Loss: 0.0047, Val Loss: 0.0077
# Epoch [110/250] - Train Loss: 0.0045, Val Loss: 0.0085
# Epoch [120/250] - Train Loss: 0.0042, Val Loss: 0.0176
# Stop early tại epoch 121

# %% [markdown]
# # Dự báo trên tập test

# %%
# Dự báo trên tập test (tạo predictions)
model.load_state_dict(torch.load('best_model_eth.pth'))
model.eval()
with torch.no_grad():
    y_pred_scaled = model(X_test).numpy()

# Chuyển list thành numpy array
y_pred_scaled = np.array(y_pred_scaled)

# %%
# chuyển scale về dạng ban đầu
y_pred = scaler_y.inverse_transform(y_pred_scaled)
y_true = scaler_y.inverse_transform(y_test_scaled)

# %%
plt.plot(y_true, label="Actual")
plt.plot(y_pred, label="Predicted")
plt.legend()
plt.grid(ls ='--')
plt.show()

# %% [markdown]
# # Đánh giá mô hình qua các chỉ số MSE, MAE, R2 Score

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
print("MSE:",mean_squared_error(y_true,y_pred))
print("RMSE:",np.sqrt(mean_squared_error(y_true,y_pred)))
print("MAE:",mean_absolute_error(y_true,y_pred))
# Out:
# MSE: 13488.141745139199
# RMSE: 116.13845937130043
# MAE: 91.40623079427085
